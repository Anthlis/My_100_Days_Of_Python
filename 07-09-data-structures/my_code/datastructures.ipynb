# %%
#!python3
numlist = [1, 2, 3, 4, 5]

numlist
# Out:
# [1, 2, 3, 4, 5]

# %%
numlist.reverse()
numlist
# Out:
# [5, 4, 3, 2, 1]

# %%
numlist.sort()
numlist
# Out:
# [1, 2, 3, 4, 5]

# %%
mystring = "julian"

for i in list(mystring):
	print(i)
# Out:
# j
# u
# l
# i
# a
# n

# %%
l = list(mystring)
t = tuple(mystring)
l
# Out:
# ['j', 'u', 'l', 'i', 'a', 'n']

# %%
t

# %%
l[0] = "b"
l
# Out:
# ['b', 'u', 'l', 'i', 'a', 'n']

# %%
t[0] = "m" # expect error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-61ea854823ec> in <module>
# ----> 1 t[0] = "m" # expect error
#
# TypeError: 'tuple' object does not support item assignment

# %%
l.pop()
l
# Out:
# ['j', 'u', 'l', 'i', 'a']

# %%
l.insert(5, "n")
l
# Out:
# ['j', 'u', 'l', 'i', 'a', 'n']

# %%
l.pop(0)
l
# Out:
# ['u', 'l', 'i', 'a', 'n']

# %%
l.insert(0, "m")
l
# Out:
# ['m', 'u', 'l', 'i', 'a', 'n']

# %%
del l[0]
l
# Out:
# ['u', 'l', 'i', 'a', 'n']

# %% [markdown]
# ###DICTS:

# %%
pybites = {'julian': 30, 'bob': 33, 'mike': 33}
pybites
# Out:
# {'julian': 30, 'bob': 33, 'mike': 33}

# %%
people = {}

# %%
people['julian'] = 30
people
# Out:
# {'julian': 30}

# %%
people['bob'] = 43
people
# Out:
# {'julian': 30, 'bob': 43}

# %%
pybites.keys()
dict_keys(['julian', 'bob', 'mike'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1f15263cf5e9> in <module>
#       1 pybites.keys()
# ----> 2 dict_keys(['julian', 'bob', 'mike'])
#
# NameError: name 'dict_keys' is not defined

# %%
pybites.values()
dict_values([30, 33, 33])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f4ad35c8b7b1> in <module>
#       1 pybites.values()
# ----> 2 dict_values([30, 33, 33])
#
# NameError: name 'dict_values' is not defined

# %%
pybites.items()
dict_items([('julian', 30), ('bob', 33), ('mike', 33)])

for keys in pybites.keys():
	print(keys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1400880b6388> in <module>
#       1 pybites.items()
# ----> 2 dict_items([('julian', 30), ('bob', 33), ('mike', 33)])
#       3
#       4 for keys in pybites.keys():
#       5         print(keys)
#
# NameError: name 'dict_items' is not defined

# %%
for values in pybites.values():
	print(values)
# Out:
# 30
# 33
# 33

# %%
for keys, values in pybites.items():
	print(keys + str(values))
# Out:
# julian30
# bob33
# mike33

# %%
for keys, values in pybites.items():
	print('%s is %d years of age' % (keys, values))
# Out:
# julian is 30 years of age
# bob is 33 years of age
# mike is 33 years of age
